# %%
import jcamp
import glob
import os
from collections import Counter
from tqdm import tqdm

jdx_path = '/Users/benji/phd/data/phd/attentivefp/jdx'
# read all jdx files in the jdx directory
# make counter dict of the yunits and xunits
yunits_counter = Counter()
xunits_counter = Counter()
xfactors_counter = Counter()
yfactors_counter = Counter()
for jdx_path in tqdm(glob.glob(os.path.join(jdx_path, '*.jdx')), desc='Processing JDX files', total=len(glob.glob(os.path.join(jdx_path, '*.jdx')))):
    try:
        jdx_data = jcamp.jcamp_readfile(jdx_path)
        
        # Check if data is absorbance and convert to transmittance if needed
        y_units = jdx_data.get('yunits', '').upper()
        if y_units not in yunits_counter:
            yunits_counter[y_units] = 1
        else:
            yunits_counter[y_units] += 1
        y_factor = jdx_data.get('yfactor', 1)
        
        # convert xunits to wavenumbers
        x_units = jdx_data.get('xunits', '').upper()
        if x_units not in xunits_counter:
            xunits_counter[x_units] = 1
        else:
            xunits_counter[x_units] += 1
        x_factor = jdx_data.get('xfactor', 1)
        if x_factor not in xfactors_counter:
            xfactors_counter[x_factor] = 1
        else:
            xfactors_counter[x_factor] += 1
        if y_factor not in yfactors_counter:
            yfactors_counter[y_factor] = 1
        else:
            yfactors_counter[y_factor] += 1
        
    except Exception as e:
        print(f"Error processing {jdx_path}: {str(e)}")

print(yunits_counter)
print(xunits_counter)
# Out:
# Processing JDX files: 100%|██████████| 16121/16121 [00:47<00:00, 338.72it/s]
# Counter({'ABSORBANCE': 8450, 'TRANSMITTANCE': 6998, '': 617, 'REFLECTANCE': 45, 'ABSORPTION INDEX': 7, 'DISPERSION INDEX': 3, '(MICROMOL/MOL)-1M-1 (BASE 10)': 1})
# Counter({'1/CM': 12464, 'MICROMETERS': 3039, '': 617, 'CM-1': 1})

# %%
print(xfactors_counter)
print(yfactors_counter)
# Out:
# Counter({1.0: 16121})
# Counter({1: 7615, 0.001: 3596, 2.3e-06: 55, 1.5e-06: 54, 1.1e-06: 51, 2.5e-06: 50, 1.4e-06: 50, 2.1e-06: 47, 1.8e-06: 46, 3.2e-06: 44, 2.6e-06: 43, 1.9e-06: 43, 9e-07: 42, 1e-06: 40, 2.4e-06: 40, 2.8e-06: 40, 3e-06: 40, 2.2e-06: 39, 8e-07: 39, 3.1e-06: 39, 2.9e-06: 38, 1.2e-06: 38, 1.6e-06: 38, 2e-06: 37, 3.5e-06: 36, 3.6e-06: 36, 1.3e-06: 36, 3.7e-06: 35, 4.9e-06: 35, 3.8e-06: 34, 3.3e-06: 33, 7e-07: 33, 3.4e-06: 32, 1.7e-06: 30, 2.7e-06: 30, 4.2e-06: 29, 3.9e-06: 29, 4.1e-06: 26, 4.5e-06: 24, 4.7e-06: 24, 4e-06: 24, 4.4e-06: 22, 4.3e-06: 21, 4.6e-06: 20, 5e-06: 20, 4.8e-06: 18, 5.3e-06: 18, 6e-07: 16, 5.1e-06: 16, 5.4e-06: 15, 5.2e-06: 13, 5.7e-06: 12, 5.8e-06: 12, 5e-07: 11, 6.1e-06: 11, 5.9e-06: 11, 6.2e-06: 10, 6.6e-06: 10, 6e-06: 10, 6.5e-06: 10, 6.7e-06: 9, 7.3e-06: 9, 5.6e-06: 9, 6.4e-06: 9, 9e-06: 8, 6.9e-06: 8, 7.7e-06: 8, 7.2e-06: 8, 9.1e-06: 7, 6.3e-06: 7, 7e-06: 6, 1.4e-05: 6, 3e-07: 6, 4e-07: 6, 7.9e-06: 6, 1e-05: 6, 7.5e-06: 6, 6.8e-06: 6, 7.4e-06: 5, 1.06e-05: 5, 5.5e-06: 5, 7.1e-06: 4, 9.4e-06: 4, 8.5e-06: 4, 1.24e-05: 4, 7.8e-06: 4, 8.7e-06: 4, 1.45e-05: 4, 1.2e-05: 4, 8.1e-06: 4, 6.5479e-05: 3, 9.9e-06: 3, 9.5e-06: 3, 1.02e-05: 3, 8.4e-06: 3, 6.6553e-05: 3, 1.53e-05: 3, 1.28e-05: 3, 8.2227e-05: 3, 5.2686e-05: 3, 8.0469e-05: 3, 1.85e-05: 3, 7.6758e-05: 3, 5.6738e-05: 3, 1.58e-05: 3, 1.1e-05: 3, 8.7646e-05: 3, 7.6e-06: 3, 7.5928e-05: 3, 1.27e-05: 3, 8.9e-06: 3, 5.7227e-05: 2, 1.52e-05: 2, 0.000137448: 2, 7.3291e-05: 2, 6.5305e-05: 2, 0.000142099: 2, 6.5918e-05: 2, 6.265e-05: 2, 8.5965e-05: 2, 0.000118466: 2, 1.33e-05: 2, 5.2148e-05: 2, 0.000145624: 2, 7.0435e-05: 2, 5.0558e-05: 2, 9.2725e-05: 2, 7.0508e-05: 2, 2.42e-05: 2, 2.47e-05: 2, 1.01e-05: 2, 5.0241e-05: 2, 6.7383e-05: 2, 1.04e-05: 2, 8.3e-06: 2, 5.0586e-05: 2, 0.000174918: 2, 8.6914e-05: 2, 7.1582e-05: 2, 6.8848e-05: 2, 1.23e-05: 2, 0.000137543: 2, 8.916e-05: 2, 6.1475e-05: 2, 0.000114496: 2, 5.5127e-05: 2, 5.0781e-05: 2, 8.2861e-05: 2, 8.378e-05: 2, 0.000132083: 2, 1.18e-05: 2, 6.1923e-05: 2, 7.9541e-05: 2, 6.0361e-05: 2, 8.1543e-05: 2, 9.2798e-05: 2, 5.3955e-05: 2, 5.7422e-05: 2, 7.1875e-05: 2, 6.2289e-05: 2, 8.3469e-05: 2, 5.8936e-05: 2, 6.9189e-05: 2, 4.7552e-05: 2, 6.9092e-05: 2, 7.2021e-05: 2, 9.2844e-05: 2, 7.9346e-05: 2, 8.8867e-05: 2, 5.3174e-05: 2, 7.7625e-05: 2, 9.6191e-05: 2, 5.1611e-05: 2, 0.000134143: 2, 5.293e-05: 2, 7.8125e-05: 2, 8.5547e-05: 2, 1.43e-05: 2, 5.7031e-05: 2, 1.68e-05: 2, 2.33e-05: 2, 1.36e-05: 2, 8.0389e-05: 2, 7.2656e-05: 2, 1.35e-05: 2, 5.5273e-05: 2, 0.000111057: 2, 9.0479e-05: 2, 5.5859e-05: 2, 5.2734e-05: 2, 5.3745e-05: 2, 7.7783e-05: 2, 5.5371e-05: 2, 5.4495e-05: 2, 8.3008e-05: 2, 9.4061e-05: 2, 5.708e-05: 2, 6.2601e-05: 2, 8.2959e-05: 2, 8.7988e-05: 2, 6.1313e-05: 2, 8.3496e-05: 2, 7.4902e-05: 2, 5.1639e-05: 2, 0.000112631: 2, 0.00013074: 2, 6.9434e-05: 2, 0.000100174: 2, 0.000132172: 2, 7.2559e-05: 2, 5.0055e-05: 2, 4.9512e-05: 2, 7.6172e-05: 2, 7.0557e-05: 2, 6.8506e-05: 2, 5.2805e-05: 2, 3.17e-05: 2, 9.6094e-05: 2, 6.0449e-05: 2, 4.9799e-05: 2, 7.0215e-05: 2, 7.5284e-05: 2, 5.3027e-05: 2, 9.0073e-05: 2, 1.59e-05: 2, 2.53e-05: 2, 5.8398e-05: 2, 1.15e-05: 2, 1.38e-05: 2, 0.000129242: 2, 9.2239e-05: 2, 9.317e-05: 2, 7.4106e-05: 2, 9.8e-06: 2, 9.4727e-05: 2, 8.2117e-05: 2, 9.2e-06: 2, 1.75e-05: 2, 5e-05: 2, 1.46e-05: 2, 0.000142218: 2, 1.11e-05: 2, 0.000102762: 2, 0.000118774: 2, 6.9791e-05: 2, 8.7643e-05: 2, 7.037e-05: 2, 5.3906e-05: 2, 0.000126135: 2, 5.3271e-05: 2, 9.5313e-05: 2, 5.3516e-05: 2, 8e-06: 2, 8.8e-06: 2, 6.3232e-05: 2, 7.0312e-05: 2, 7.4658e-05: 2, 7.6361e-05: 2, 4.31e-05: 2, 5.3976e-05: 2, 9.1193e-05: 2, 4.9121e-05: 2, 0.000101785: 1, 0.000101141: 1, 6.7465e-05: 1, 7.2299e-05: 1, 0.000186209: 1, 6.1609e-05: 1, 2.41e-05: 1, 9.8245e-05: 1, 5.0879e-05: 1, 7.7005e-05: 1, 0.000168344: 1, 0.000108441: 1, 0.000118732: 1, 0.000149255: 1, 0.000129877: 1, 4.39e-05: 1, 0.000125256: 1, 0.000162115: 1, 7.8985881e-10: 1, 0.000160239: 1, 6.1328e-05: 1, 7.6797e-05: 1, 0.000140485: 1, 8.0991e-05: 1, 0.000131863: 1, 5. ...
